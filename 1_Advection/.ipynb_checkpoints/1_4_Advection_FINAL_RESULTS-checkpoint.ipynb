# %% [markdown]
# ### **libs**

# %%
import warnings
warnings.filterwarnings('ignore')

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import copy
from tqdm import tqdm
import torch

import sys
sys.path.append('D:\diplom_2\my_test')
import my_funcs as mf

import my_advection_funcs as mtf

# %% [markdown]
# ### **read data**

# %%
path_data=fr'data/advection_v_fact_tau=0.009_n=101.csv'

# %%
data=pd.read_csv(path_data,header=None)
data=data.T
print(data.shape)
# Out:
# (101, 89)

# %%
data=np.array(data)

# %%
plt.plot(data[:,-1])

# %% [markdown]
# ### **read net**

# %%
path_model=fr'data/models/model_advection_n=101_[1, 16, 2, 0.01, 2, True]_WDactRK3_seed_1.pth'

# %%
net=torch.load(path_model)

# %% [markdown]
# ### **view predicts**

# %%
#device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

v_train = torch.tensor(data, requires_grad=True, dtype=torch.float, device=device)

method='RK3'
L=1

# %%
NN_sim,T_sim,x_sim=mf.make_simulation(net,v_coarse,L,Lxc,dtc)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 88/88 [00:00<00:00, 1039.54it/s]

# %%
mf.view_results(T_sim,x_sim,NN_sim,v_train.data.numpy())
