# %%
import warnings
warnings.filterwarnings('ignore')

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import copy
from tqdm import tqdm


import my_advection_funcs as maf

# %% [markdown]
# ### **0. Fact**

# %%
n=101
L=1
T=1
kurant=0.5

h=L/(n-1)
tau=kurant*h

b=(n-1)*0.1 #width % of L

l=[i/(n-1) for i in range(0,n)]
v=[1 if i in range(1,int(b)+1) else 0 for i in range(0,n) ]
print('Доля 1:',np.round(100*v.count(1)/len(v),3))

plt.plot(l,v,'-*')
plt.grid()
# Out:
# Доля 1: 9.901

# %%
folder_to_save_png='data/output/png/'

# %% [markdown]
# ### **1. Upwind 1st order**

# %%
# %%time

final_time=0.2
fact_v,_=maf.advection_upwind(v,final_time,1,h,n)
new_v_0_50,_=maf.advection_upwind(v,final_time,0.5,h,n)
new_v_0_75,_=maf.advection_upwind(v,final_time,0.75,h,n)
new_v_0_90,_=maf.advection_upwind(v,final_time,0.90,h,n)
new_v_0_25,_=maf.advection_upwind(v,final_time,0.25,h,n)
plt.figure(figsize=(8,6))
plt.plot(l,fact_v,'--',label='Точное решение : С = 1',color='black')
plt.plot(l,new_v_0_90,'-o',label=r'Upwind (1-й порядок) : С = 0.9',color='blue')
plt.plot(l,new_v_0_75,'-o',label=r'Upwind (1-й порядок) : С = 0.75',color='orange')
plt.plot(l,new_v_0_50,'-*',label=r'Upwind (1-й порядок) : С = 0.5',color='red')
plt.plot(l,new_v_0_25,'-*',label=r'Upwind (1-й порядок) : С = 0.25',color='cyan')
plt.legend()
plt.grid()
plt.xlabel('x')
plt.ylabel('V')
plt.title(fr'Решение при t = {final_time}')
plt.savefig(folder_to_save_png+'upwind_1order_1.png')

final_time=0.8
fact_v,_=maf.advection_upwind(v,final_time,1.0,h,n)
new_v_0_50,_=maf.advection_upwind(v,final_time,0.5,h,n)
new_v_0_75,_=maf.advection_upwind(v,final_time,0.75,h,n)
new_v_0_90,_=maf.advection_upwind(v,final_time,0.90,h,n)
new_v_0_25,_=maf.advection_upwind(v,final_time,0.25,h,n)
plt.figure(figsize=(8,6))
plt.plot(l,fact_v,'--',label='Точное решение : С = 1',color='black')
plt.plot(l,new_v_0_90,'-o',label=r'Upwind (1-й порядок) : С = 0.9',color='blue')
plt.plot(l,new_v_0_75,'-o',label=r'Upwind (1-й порядок) : С = 0.75',color='orange')
plt.plot(l,new_v_0_50,'-*',label=r'Upwind (1-й порядок) : С = 0.5',color='red')
plt.plot(l,new_v_0_25,'-*',label=r'Upwind (1-й порядок) : С = 0.25',color='cyan')
plt.legend()
plt.grid()
plt.xlabel('x')
plt.ylabel('V')
plt.title(fr'Решение при t = {final_time}')
plt.savefig(folder_to_save_png+'upwind_1order_2.png')
# Out:
# CPU times: total: 359 ms
# Wall time: 406 ms

# %% [markdown]
# ### **2. Upwind 3rd order**

# %%
# %%time

final_time=0.2
fact_v,_=maf.advection_upwind(v,final_time,1,h,n)
new_v_0_50,_=maf.advection_upwind(v,final_time,0.5,h,n,order=3)
new_v_0_75,_=maf.advection_upwind(v,final_time,0.75,h,n,order=3)
new_v_0_90,_=maf.advection_upwind(v,final_time,0.90,h,n,order=3)
new_v_0_25,_=maf.advection_upwind(v,final_time,0.25,h,n,order=3)
plt.figure(figsize=(8,6))
plt.plot(l,fact_v,'--',label='Точное решение : С = 1',color='black')
plt.plot(l,new_v_0_90,'-o',label=r'Upwind (3-й порядок) : С = 0.9',color='blue')
plt.plot(l,new_v_0_75,'-o',label=r'Upwind (3-й порядок): С = 0.75',color='orange')
plt.plot(l,new_v_0_50,'-*',label=r'Upwind (3-й порядок): С = 0.5',color='red')
plt.plot(l,new_v_0_25,'-*',label=r'Upwind (3-й порядок): С = 0.25',color='cyan')
plt.legend()
plt.grid()
plt.xlabel('x')
plt.ylabel('V')
plt.title(fr'Решение при t = {final_time}')
plt.savefig(folder_to_save_png+'upwind_3order_1.png')

final_time=0.8
fact_v,_=maf.advection_upwind(v,final_time,1.0,h,n)
new_v_0_50,_=maf.advection_upwind(v,final_time,0.5,h,n,order=3)
new_v_0_75,_=maf.advection_upwind(v,final_time,0.75,h,n,order=3)
new_v_0_90,_=maf.advection_upwind(v,final_time,0.90,h,n,order=3)
new_v_0_25,_=maf.advection_upwind(v,final_time,0.25,h,n,order=3)
plt.figure(figsize=(8,6))
plt.plot(l,fact_v,'--',label='Точное решение : С = 1',color='black')
plt.plot(l,new_v_0_90,'-o',label=r'Upwind (3-й порядок): С = 0.9',color='blue')
plt.plot(l,new_v_0_75,'-o',label=r'Upwind (3-й порядок): С = 0.75',color='orange')
plt.plot(l,new_v_0_50,'-*',label=r'Upwind (3-й порядок): С = 0.5',color='red')
plt.plot(l,new_v_0_25,'-*',label=r'Upwind (3-й порядок): С = 0.25',color='cyan')
plt.legend()
plt.grid()
plt.xlabel('x')
plt.ylabel('V')
plt.title(fr'Решение при t = {final_time}')
plt.savefig(folder_to_save_png+'upwind_3order_2.png')
# Out:
# CPU times: total: 4.33 s
# Wall time: 4.51 s

# %% [markdown]
# ### **3.Central-difference 2-order**

# %%
# %%time

final_time=0.2
fact_v,_=maf.advection_upwind(v,final_time,1,h,n)
new_v_0_90,_=maf.advetion_central_diff(v,final_time,0.90,h,n)
new_v_0_25,_=maf.advetion_central_diff(v,final_time,0.25,h,n)
plt.figure(figsize=(8,6))
plt.plot(l,fact_v,'--',label='Точное решение : С = 1',color='black')
plt.plot(l,new_v_0_90,'-o',label=r'Центральная разность (2-й порядок) : С = 0.9',color='blue')
plt.plot(l,new_v_0_25,'-*',label=r'Центральная разность (2-й порядок) : С = 0.25',color='cyan')
plt.legend()
plt.grid()
plt.xlabel('x')
plt.ylabel('V')
plt.title(fr'Решение при t = {final_time}')
plt.savefig(folder_to_save_png+'centr_diff_2order_1.png')

final_time=0.8
fact_v,_=maf.advection_upwind(v,final_time,1,h,n)
new_v_0_90,_=maf.advetion_central_diff(v,final_time,0.90,h,n)
new_v_0_25,_=maf.advetion_central_diff(v,final_time,0.25,h,n)
plt.figure(figsize=(8,6))
plt.plot(l,fact_v,'--',label='Точное решение : С = 1',color='black')
plt.plot(l,new_v_0_90,'-o',label=r'Центральная разность (2-й порядок) : С = 0.9',color='blue')
plt.plot(l,new_v_0_25,'-*',label=r'Центральная разность (2-й порядок) : С = 0.25',color='cyan')
plt.legend()
plt.grid()
plt.xlabel('x')
plt.ylabel('V')
plt.title(fr'Решение при t = {final_time}')
plt.savefig(folder_to_save_png+'centr_diff_2order_2.png')
# Out:
# CPU times: total: 2.42 s
# Wall time: 2.58 s

# %% [markdown]
# ### **4.Central-difference 4-order**

# %%
# %%time

final_time=0.2
fact_v,_=maf.advection_upwind(v,final_time,1,h,n)
new_v_0_90,_=maf.advetion_central_diff(v,final_time,0.90,h,n,order=4)
new_v_0_25,_=maf.advetion_central_diff(v,final_time,0.25,h,n,order=4)
plt.figure(figsize=(8,6))
plt.plot(l,fact_v,'--',label='Точное решение : С = 1',color='black')
plt.plot(l,new_v_0_90,'-o',label=r'Центральная разность (4-й порядок) : С = 0.9',color='blue')
plt.plot(l,new_v_0_25,'-*',label=r'Центральная разность (4-й порядок) : С = 0.25',color='cyan')
plt.legend()
plt.grid()
plt.xlabel('x')
plt.ylabel('V')
plt.title(fr'Решение при t = {final_time}')
plt.savefig(folder_to_save_png+'centr_diff_4order_1.png')

final_time=0.8
fact_v,_=maf.advection_upwind(v,final_time,1,h,n)
new_v_0_90,_=maf.advetion_central_diff(v,final_time,0.90,h,n,order=4)
new_v_0_25,_=maf.advetion_central_diff(v,final_time,0.25,h,n,order=4)
plt.figure(figsize=(8,6))
plt.plot(l,fact_v,'--',label='Точное решение : С = 1',color='black')
plt.plot(l,new_v_0_90,'-o',label=r'Центральная разность (4-й порядок) : С = 0.9',color='blue')
plt.plot(l,new_v_0_25,'-*',label=r'Центральная разность (4-й порядок) : С = 0.25',color='cyan')
plt.legend()
plt.grid()
plt.xlabel('x')
plt.ylabel('V')
plt.title(fr'Решение при t = {final_time}')
plt.savefig(folder_to_save_png+'centr_diff_4order_2.png')
# Out:
# CPU times: total: 4.02 s
# Wall time: 4.17 s
