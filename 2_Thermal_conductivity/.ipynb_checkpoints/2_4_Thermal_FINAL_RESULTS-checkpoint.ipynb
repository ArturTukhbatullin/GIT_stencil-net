# %% [markdown]
# ### **libs**

# %%
import warnings
warnings.filterwarnings('ignore')

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import copy
from tqdm import tqdm
import torch

import sys
sys.path.append('D:\diplom_2\my_test')
import my_funcs as mf

import my_thermal_funcs as mtf

# %% [markdown]
# ### **read data**

# %%
path_data=fr'data/thermal_v_fact_tau=0.0012500000000000002_n=21.csv'

# %%
data=pd.read_csv(path_data,header=None)
data=data.T
print(data.shape)
# Out:
# (21, 242)

# %%
data=np.array(data)

# %%
plt.plot(data[:,0],'-*',label='t=t_0')
plt.plot(data[:,-1],'-*',label='t=t_last')
plt.grid()
plt.legend()

# %%
[0.9**j for j in range(4+1)]
# Out:
# [1.0, 0.9, 0.81, 0.7290000000000001, 0.6561]

# %%
net.layer[0].weight
# Out:
# Parameter containing:
# tensor([[ 9.9896e-02, -7.8272e-02,  2.8790e-01,  2.2451e-02,  3.6604e-01,
#          -1.7416e-01, -3.1499e-02,  1.3695e-01,  1.8906e-01],
#         [-1.5841e-02,  2.0402e-01, -3.3418e-01,  8.1879e-03,  1.0397e-01,
#           6.2213e-02,  2.3487e-01,  3.4431e-02, -3.4450e-01],
#         [ 1.0737e-01,  6.1810e-02,  7.0048e-02,  2.7591e-01, -6.9509e-02,
#          -1.6519e-01, -1.4686e-01,  2.8288e-01,  1.9749e-02],
#         [ 1.3109e-01, -4.1311e-02,  1.7788e-01, -2.7457e-01, -2.1999e-01,
#           7.7960e-02,  1.1250e-01,  5.6922e-02, -5.4277e-02],
#         [-6.4454e-02,  1.2936e-01, -2.3871e-01, -1.4174e-01, -1.5430e-01,
#          -4.2495e-01,  1.7392e-01,  2.6912e-01, -1.4057e-01],
#         [-2.6834e-02, -2.4572e-01,  5.8805e-02, -1.4526e-01, -1.5972e-01,
#           2.2448e-01,  1.7791e-02,  3.2273e-02, -1.3583e-02],
#         [ 1.6702e-02, -3.7531e-02, -1.2323e-01,  4.4735e-04, -3.3034e-01,
#          -1.3605e-01,  1.1077e-01,  7.1050e-02,  4.6333e-02],
#         [ 7.5585e-02,  1.7492e-01, -1.6037e-02,  4.6185e-02, -5.4578e-01,
#          -4.0280e-01,  7.2217e-02, -8.8346e-02,  1.8036e-02],
#         [-7.8854e-02,  1.1644e-01,  3.0423e-01,  1.3329e-01,  4.1438e-01,
#          -1.0577e-01, -5.7088e-02,  1.3088e-01, -2.3407e-01],
#         [-1.1229e-01,  1.6538e-01,  5.5425e-02, -2.6028e-01,  8.3374e-02,
#           1.7210e-01, -7.1748e-03, -1.0543e-01,  2.5426e-01],
#         [-1.4676e-02, -2.9562e-02,  8.2797e-02,  3.2939e-02, -5.1519e-01,
#          -3.5895e-01,  2.4976e-01, -9.5613e-03,  1.5238e-01],
#         [ 1.1431e-02,  5.7243e-02, -5.2950e-02,  2.5010e-01,  2.9501e-01,
#          -9.1121e-03, -1.6021e-01, -1.0650e-01, -6.0273e-02],
#         [-6.4639e-02,  4.1745e-03, -9.2843e-02, -7.7586e-02,  2.7517e-01,
#         [ 2.2464e-01, -3.4810e-01,  1.4553e-01,  4.8525e-01,  3.0798e-01,
#          -1.8026e-01,  1.8063e-01, -1.1138e-01,  5.1054e-02],
#         [ 2.6094e-02,  2.0167e-01,  1.7306e-01, -4.2473e-01, -4.4274e-01,
#           2.5359e-01, -3.0216e-02, -1.3558e-01, -1.6711e-01]],
#        requires_grad=True)

# %% [markdown]
# ### **re-generate new data (with add time>> time_train)**

# %%
generate_flg=True # True - генерация, False - чтение уже сгенерированных
# generate_flg=False

n=21 #число узлов
L=1 # длина расчт области
T=0.3 #конечное время (было 0.3 на трейне)
kurant=0.5

h=L/(n-1)
b=(n-1)*0.1*L #width % of L (длина участка с v=1, составляет 10% от расчт области)
# IC
v=[0 for i in range(0,n)]
# v=[np.sin(6.6*np.pi*i/n) for i in range(0,n)] #sin(6.6x)
# BC
v[0]=0
v[-1]=1

plt.plot(v,'-*')
plt.grid()

CUSTOM_TAU=kurant*h**2#0.009
# CUSTOM_TAU=0.01
data,x_lst,tau,time_lst=mtf.generate_data(generate_flg,v,T,L,0.5,h,n,CUSTOM_TAU=CUSTOM_TAU,save_flg=True)
print(data.shape)
# Out:
# Генерация данных
# 242 21
# 21 242
# (21, 242)

# %%
plt.plot(data[:,-1],'-*')

# %%
# net.layer[0].weight

# %% [markdown]
# ### **read net**

# %%
path_model=fr'data/models/model_thermal_n=21_[9, 64, 4, 0.01, 2, False]_WDactRK3_seed_1.pth'

# %%
net=torch.load(path_model)

# %%
net.layer
# Out:
# ModuleList(
#   (0): Linear(in_features=9, out_features=64, bias=True)
#   (1-3): 3 x Linear(in_features=64, out_features=64, bias=True)
#   (4): Linear(in_features=64, out_features=1, bias=True)
# )

# %% [markdown]
# ### **subsampling**

# %%
# t_factor = 10  # time subsample factor 
# s_factor = 4   # space subsample factor

t_factor = 10  # time subsample factor 
s_factor = 4   # space subsample factor

h=0.01
tau=0.00125
n=21
train_split=0.7
Tsim=len(data[0])
dxc,dtc,coarse_t,coarse_x,v_coarse,Lxc,\
Ltc,v_coarse_train,v_coarse_test=mf.subsampling(s_factor,t_factor,h,tau,Tsim,n,data,train_split=train_split)
# Out:
# full_sample (6, 105)
# train (6, 73)
# test (6, 32)

# %% [markdown]
# ### **view predicts**

# %%
#device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

v_train = torch.tensor(data, requires_grad=True, dtype=torch.float, device=device)

method='RK3'
L=1

# %%
Lxc,L
# Out:
# (6, 1)

# %% [markdown]
# ##### **1. on subsampling data**

# %%
NN_sim,T_sim,x_sim=mf.make_simulation(net,v_coarse,L,Lxc,dtc)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 104/104 [00:00<00:00, 718.85it/s]

# %%
mf.view_results(T_sim,x_sim,NN_sim,v_coarse,n=10)

# %% [markdown]
# ##### **2. on full data**

# %%
NN_sim,T_sim,x_sim=mf.make_simulation(net,data,L=4,Lxc=21,dtc=dtc)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 241/241 [00:00<00:00, 486.54it/s]

# %%
mf.view_results(T_sim,x_sim,NN_sim,data,n=5)
